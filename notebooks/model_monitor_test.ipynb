# %%
from credit_risk_modeling.model_monitor import ModelMonitor
import pandas as pd

# %%
monitor = ModelMonitor()
# Out:
# 2026-02-12 21:44:58.717 | INFO     | credit_risk_modeling.model_monitor:__init__:49 - ✓ ModelMonitor initialized with baseline: {'approval_rate': 0.65, 'avg_pd': 0.15, 'avg_confidence': 0.85}

# %%
scoring_results_df = pd.read_csv("../data/processed/test_results.csv")

# %%
monitoring_metrics = monitor.monitor_batch(scoring_results_df)
# Out:
# 2026-02-12 21:44:58.760 | INFO     | credit_risk_modeling.model_monitor:monitor_batch:161 - ✓ Monitoring complete: 5 predictions
# 2026-02-12 21:44:58.760 | INFO     | credit_risk_modeling.model_monitor:monitor_batch:162 -   Approval rate: 80.0%
# 2026-02-12 21:44:58.760 | INFO     | credit_risk_modeling.model_monitor:monitor_batch:163 -   Avg PD: 0.206
# 2026-02-12 21:44:58.760 | INFO     | credit_risk_modeling.model_monitor:monitor_batch:164 -   Avg Confidence: 0.013
# 2026-02-12 21:44:58.760 | WARNING  | credit_risk_modeling.model_monitor:monitor_batch:167 - ⚠️  4 alerts detected:
# 2026-02-12 21:44:58.760 | WARNING  | credit_risk_modeling.model_monitor:monitor_batch:169 -     ⚠️  APPROVAL RATE DRIFT: 80.0% (baseline: 65.0%, diff: +15.0%)
# 2026-02-12 21:44:58.760 | WARNING  | credit_risk_modeling.model_monitor:monitor_batch:169 -     ⚠️  PD DRIFT: 0.206 (baseline: 0.150, relative change: +37.6%)
# ...
